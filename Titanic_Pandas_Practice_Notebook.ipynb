# %% [markdown]
# # 🧩 Titanic Dataset Exploration with pandas
#
# 🎯 **Goal:**
# In this notebook, you'll explore the Titanic dataset using **pandas**.
# You'll practice the most common pandas functions for data inspection, selection, filtering, cleaning, and analysis.
#
# For each function in the list below:
# 1. Explain what it does (in your own words, in a Markdown cell).
# 2. Give at least **two examples** using the Titanic dataset.
# 3. Add a short comment about the output or why it’s useful.

# %%
import pandas as pd

# Load Titanic dataset
# (Make sure titanic.csv is in the same folder as this notebook)
df = pd.read_csv("titanic_dataset.csv")

# %% [markdown]
# ## 🧠 Step 1: Inspecting the Data
#
# Functions to explore:
# - df.head()
# - df.tail()
# - df.info()
# - df.describe()
# - df.shape
# - df.columns

# %% [markdown]
# df.head muestras las primer filas del dataframe tomando por defecto 5

# %%
# Ejemplo: df.head()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Ejemplo 2
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# df.tail muestra las últimas filas del dataframe tomando por defecto 5

# %%
#Ejemplo: df.tail()
df.tail() #Últimas 5 filas
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Ejemplo 2
df.tail(2)  #Últimas 2 filas
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %% [markdown]
# df.info muestra un resumen de datos del DataFrame estos son:
# Cantidad de filas y columnas
# Nombres de las columnas
# Tipos de datos
# Valores nulos

# %%
#Ejemplo: df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Ejemplo 2 
df2 = pd.DataFrame({
    "Nombre": ["Ana", "Luis", "María"],
    "Edad": [23, None, 19],
    "Ciudad": ["Madrid", "Sevilla", "Barcelona"]
})
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nombre  3 non-null      object
#  1   Edad    2 non-null      float64
#  2   Ciudad  3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 204.0+ bytes

# %% [markdown]
# df.describe() muestra datos estadísticos de las columnas con valores numéricos, algunos de estos datos estos son:
# Media
# Desviación
# Mínimo
# Máximo
# Porcentajes

# %%
#Ejemplo: df.describe()
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Ejemplo 2
df2 = pd.DataFrame({
    "Altura": [1.75, 1.60, 1.82, 1.90],
    "Peso": [70, 55, 80, 90]
})
df2.describe()
# Out:
#          Altura       Peso
# count  4.000000   4.000000
# mean   1.767500  73.750000
# std    0.127377  14.930394
# min    1.600000  55.000000
# 25%    1.712500  66.250000
# 50%    1.785000  75.000000
# 75%    1.840000  82.500000
# max    1.900000  90.000000

# %% [markdown]
# df.shape() devuelve una tupla con las dimensiones del dataframe

# %%
#Ejemplo: df.shape()
df.shape
# Out:
# (891, 12)

# %%
#Ejemplo 2
filas, columnas = df.shape
print(f"El titanic_dataset tiene {filas} filas y {columnas} columnas")
# Out:
# El titanic_dataset tiene 891 filas y 12 columnas

# %% [markdown]
# df.columns() devuelve una lista con los nombres de las columnas

# %%
#Ejemplo: df.columns
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #Ejemplo: df.columns
# ----> 2 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
#Ejemplo 2
for columna in df.columns:
    print("Columna:", columna)

# %% [markdown]
# ## 🔍 Step 2: Selecting Data
# Functions to explore:
# - df["column"]
# - df[["col1", "col2"]]
# - df.loc[]
# - df.iloc[]

# %% [markdown]
# df["column"] selecciona una columna y devuelve una serie de una columna con su índice

# %%
# Ejemplo: df["column"]

df["Age"].head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
#Ejemplo 2
df["Sex"].head()

# %% [markdown]
# df[["col1","col2"]] selecciona varias columnas a la vez y devuelve un Dataframe

# %%
# Ejemplo: df[["col","col2"]] 
df[["Sex", "Age", "Survived"]].head()

# %%
# Ejemplo 2
df[["Pclass", "Survived"]].head()

# %% [markdown]
# df.loc[] Selecciona filas y columnas por etiquetas

# %%
#Ejemplo: df.loc[]
df.loc[0, "Name"]

# %%
#Ejemplo 2
df.loc[0:4, ["Name", "Age", "Sex"]]

# %% [markdown]
# df.iloc[] Selecciona filas y columnas por su posición numérica

# %%
#Ejemplo: df.iloc[]
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
#Ejemplo 2
df.iloc[0:3, 1:4]

# %% [markdown]
# ## 🔎 Step 3: Filtering Rows
#
# Functions to explore:
# - df[df["Age"] > 30]
# - df.query("Sex == 'female' and Survived == 1")

# %% [markdown]
# df[df["Age"] > 30] filtra y devuelve las filas donde la columna cumple con las condiciones asignadas

# %%
#Ejemplo : df[df["column"]]
df[df["Age"] > 50].head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 6             7         0       1           McCarthy, Mr. Timothy J    male
# 11           12         1       1          Bonnell, Miss. Elizabeth  female
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
# 33           34         0       2             Wheadon, Mr. Edward H    male
# 54           55         0       1    Ostby, Mr. Engelhart Cornelius    male
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 6   54.0      0      0       17463  51.8625   E46        S
# 11  58.0      0      0      113783  26.5500  C103        S
# 15  55.0      0      0      248706  16.0000   NaN        S
# 33  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 54  65.0      0      1      113509  61.9792   B30        C
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# ...

# %%
#Ejemplo 2
df[(df["Age"] > 30) & (df["Sex"] == "male")]

# %% [markdown]
# df.query() usa la sintaxis de consulta tipo SQL para filtrar filas don se cumplan condiciones expresadas

# %%
#Ejemplo df.query()
df.query("Sex == 'female' and Survived == 1").head()

# %%
#Ejemplo 2
df.query("Sex == 'male' and Survived == 0 and Age < 20").head()

# %% [markdown]
# ## 🧹 Step 4: Handling Missing Data
#
# Functions to explore:
# - df.isna()
# - df.isna().sum()
# - df.dropna()
# - df.fillna()

# %% [markdown]
# df.isna() Devuelve un DataFrame de valores boolean indicando si las cada celda tiene valor NaN o None(True si falta el dato)

# %%
#Ejemplo df.isna()
df.isna()

# %%
#Ejemplo 2
df[df.isna().any(axis=1)].head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %% [markdown]
# df.isna().sum() Cuenta cuantos valores NaN hay en cada columna

# %%
# Ejemplo df.isna.sum()
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Ejemplo 2
df.isna().sum().sum()
# Out:
# np.int64(866)

# %% [markdown]
# df.dropna() Elimina filas o columnas con valores nulos

# %%
# Ejemplo df.dropna()
df_sin_nulos = df.dropna()
df_sin_nulos

# %%
#Ejemplo 2
df_col = df.dropna(axis=1)
df_col

# %% [markdown]
# df.fillna() Rellena los valores nulos con un valor

# %%
# Ejemplo df.fillna()
df_text = df.fillna("Desconocido")
df_text.head

# %%
# Ejemplo 2
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Age"].head()

# %% [markdown]
# ## 📊 Step 5: Grouping and Aggregating
#
# Functions to explore:
# - df.groupby("Sex")["Survived"].mean()
# - df["Fare"].mean()
# - df["Age"].median()

# %% [markdown]
# df.groupby("column1")["column2"] agrupa los datos por la columna1 y calcula el promedio de la segunda columna para cada grupo

# %%
# Ejemplo groupby()
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Ejemplo 2
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# df["colum1"].mean() calcula la media de la columna

# %%
#Ejemplo .mean()
df["Fare"].mean()
# Out:
# np.float64(32.204207968574636)

# %%
# Ejemplo 2
df["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# df.["columna"].median() calcula la mediana de la columna

# %%
# Ejemplo .median()
df["Age"].median()

# %%
# Ejemplo 2
df["Fare"].median()
# Out:
# np.float64(14.4542)

# %% [markdown]
# ## 📈 Step 6: Sorting and Counting
#
# Functions to explore:
# - df.sort_values("Age")
# - df["Sex"].unique()
# - df["Pclass"].value_counts()

# %% [markdown]
# df.sort_values("column") Ordena los valores de la columna de menos a mayor

# %%
# Ejemplo df.sort.values()
df.sort_values("Age").head()

# %%
# Ejemplo 2 (descendente)
df.sort_values("Age", ascending=False).head()

# %% [markdown]
# df.["column"].unique() devuelve un array con los valores unicos de las columnas

# %%
# Ejemplo df[""].unique()
df["Sex"].unique()

# %%
# Ejemplo 2
df["Age"].unique()

# %% [markdown]
# df["column"].value_counts() cuenta cuantas veces aparece cada valor en la columna

# %%
# Ejemplo df[""].value_counts()
df["Pclass"].value_counts()

# %%
# Ejemplo 2
df["Sex"].value_counts()

# %% [markdown]
# ## ⚙️ Step 7: Creating or Modifying Columns
#
# Functions to explore:
# - df.assign()
# - df.apply()
# - df["new_col"] = ...
# - pd.concat()
# - pd.merge()

# %%
# Example: Create new column
df["Fare_per_Age"] = df["Fare"] / df["Age"]
df[["Age", "Fare", "Fare_per_Age"]].head()

# %% [markdown]
# ## 💾 Step 8: Exporting Data
#
# Function to explore:
# - df.to_csv("output.csv", index=False)

# %%
# Example: Save cleaned data
df.to_csv("titanic_cleaned.csv", index=False)

# %% [markdown]
# ## 🧩 Step 9: Summary
#
# Reflect on what you learned:
# - Which functions were most useful?
# - What insights did you gain from the Titanic dataset?
